# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

# %%
model=init_chat_model('gpt-4.1')
response=model.invoke("hello , how are you")

# %%
model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("hi how are u")
response.content

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:llama-3.1-8b-instant")
response=model.invoke("hi how are u")
response
# Out:
# AIMessage(content="I'm just a computer program, so I don't have feelings like humans do, but I'm functioning properly and ready to help with any questions or tasks you have. How can I assist you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 39, 'total_tokens': 81, 'completion_time': 0.082507716, 'completion_tokens_details': None, 'prompt_time': 0.001810256, 'prompt_tokens_details': None, 'queue_time': 0.051440073, 'total_time': 0.084317972}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d80ff-f0cf-7220-8c71-3c83808fb05a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 42, 'total_tokens': 81})

# %%
for chunk in model.stream('why do parrots have colorful feathers'):
    print(chunk.text, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| due| to| several| reasons|:
#
# |1|.| **|Ev|olution|ary| advantages|**:| Bright|ly| colored| feathers| may| serve| as| a| visual| signal| to| other| par|rots|,| indicating| age|,| sex|,| reproductive| status|,| and| social| status|.| This| helps| them| attract| mates|,| establish| dominance|,| and| maintain| social| hier|arch|ies| within| their| f|locks|.
# |2|.| **|M|ating| and| court|ship|**:| Vibr|ant| colors| may| play| a| crucial| role| in| attracting| potential| mates|.| M|ales| with| the| most| impressive| plum|age| may| be| more| attractive| to| females|,| increasing| their| chances| of| reproductive| success|.
# |3|.| **|Warning| signals|**:| Bright| colors| can| serve| as| a| warning| to| predators| that| a| par|rot| is| toxic|,| dist|ast|eful|,| or| difficult| to| catch|.| Many| par|rots| have| brightly| colored| feathers| on| their| heads|,| backs|,| or| wings|,| which| may| deter| potential| predators|.
# |4|.| **|Communication|**:| Color|ful| feathers| can| also| be| used| for| communication| among| par|rots|.| They| may| use| specific| color| patterns| or| displays| to| signal| aggression|,| court|ship|,| or| alarm| calls|.
# |5|.| **|Social| status|**:| In| some| species|,| the| intensity| or| brightness| of| an| individual|'s| color|ation| can| indicate| its| social| status| within| the| flock|.| Domin|ant| birds| may| have| more| vibrant| colors|,| while| subordinate| birds| may| have| dull|er| or| more| muted| plum|age|.
# |6|.| **|Environmental| adaptations|**:| In| some| cases|,| the| color|ation| of| a| par|rot|'s| feathers| may| be| an| adaptation| to| its| environment|.| For| example|,| a| par|rot| with| bright| colors| on| its| back| may| be| able| to| blend| in| with| the| bright| colors| of| its| surroundings|,| making| it| more| difficult| for| predators| to| spot|.
# |7|.| **|P|ig|mentation|**:| The| color| of| a| par|rot|'s| feathers| is| determined| by| the| pig|ments| present| in| the| feathers|,| such| as| melan|in|,| car|oten|oids|,| and| por|ph|yr|ins|.| These| pig|ments| can| be| produced| by| the| par|rot|'s| body| or| obtained| from| its| diet|.
#
# |It|'s| worth| noting| that| not| all| par|rots| are| brightly| colored|.| Some| species|,| such| as| the| African| Grey| Par|rot|,| have| more| subdued| color|ation|,| while| others|,| like| the| Mac|aw|,| are| known| for| their| vibrant| plum|age|.|||

# %%
responses=model.batch(["why do parrots have colorful feathers","why do airplanes fly"])
for response  in responses:
    print(response)
# Out:
# content='Parrots have colorful feathers due to a combination of factors, primarily related to their biology, behavior, and evolutionary history. Here are some reasons why parrots have vibrant, colorful feathers:\n\n1. **Attracting mates**: Bright colors and striking patterns serve as a visual signal to attract potential mates. Male parrots often display their vibrant feathers to showcase their health, genetic quality, and suitability as a partner. This helps them to compete with other males for mating opportunities.\n2. **Communicating with other parrots**: Colorful feathers help parrots to communicate with each other through visual displays. They use their plumage to signal aggression, courtship, or warning calls to other parrots. For example, some parrot species display a specific coloration or pattern to indicate aggression or territorial behavior.\n3. **Camouflage and protection**: While it might seem counterintuitive, some parrot species have evolved to have colorful feathers that blend in with their surroundings. This is particularly true for parrots that live in dense, tropical forests. Their bright colors can help them to blend in with the foliage, making it harder for predators to spot them.\n4. **Warning signals**: Bright colors can serve as a warning signal to potential predators that a parrot is distasteful or toxic. Some parrot species have evolved to have brightly colored feathers that signal their toxicity, making them less attractive to predators.\n5. **Genetic variation and expression**: Parrots, like all animals, have genetic variation that influences the expression of their traits, including feather color. Some parrot species have a high degree of genetic diversity, which can result in a wide range of colorful plumage.\n6. **Evolutionary history**: Parrots have evolved over millions of years, and their colorful feathers are a result of their evolutionary history. Many parrot species have been influenced by their environments, social structures, and predation pressures, which have shaped their plumage over time.\n7. **Pigmentation and melanin**: Parrots have a unique type of melanin, called eumelanin, which is responsible for the production of dark colors. They also have a type of melanin called pheomelanin, which produces red and yellow colors. The combination of these melanins and the structure of their feathers allows parrots to display a wide range of colors.\n\nIn summary, parrots have colorful feathers due to a combination of factors, including attracting mates, communicating with other parrots, camouflage and protection, warning signals, genetic variation and expression, evolutionary history, and pigmentation and melanin.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 522, 'prompt_tokens': 42, 'total_tokens': 564, 'completion_time': 1.035927818, 'completion_tokens_details': None, 'prompt_time': 0.003431545, 'prompt_tokens_details': None, 'queue_time': 0.142816395, 'total_time': 1.039359363}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d8101-7e79-7870-8d5b-94c787c936bc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 522, 'total_tokens': 564}
# content="Airplanes fly due to the principles of aerodynamics and the four forces of flight. These forces are:\n\n1. **Lift**: The upward force that opposes the weight of the plane and keeps it flying. Lift is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the plane moves forward, the air flowing over the curved surface of the wing must travel faster than the air flowing along the flat surface underneath. This creates an area of lower air pressure above the wing and an area of higher air pressure below it, resulting in an upward force called lift.\n2. **Weight**: The downward force that is the combined weight of the plane, passengers, cargo, and fuel.\n3. **Thrust**: The forward force that propels the plane through the air. Thrust is created by the plane's engines, which produce a stream of high-speed air that exits the back of the plane.\n4. **Drag**: The backward force that opposes the motion of the plane. Drag is created by air resistance, which slows the plane down.\n\nWhen an airplane is in flight, these four forces are in balance. The lift generated by the wings counteracts the weight of the plane, while the thrust generated by the engines counteracts the drag created by air resistance.\n\nThe shape of the wing is critical to creating lift. The curved upper surface of the wing is called the cambered surface, and the flat lower surface is called the flat plate. As the air flows over the wing, it follows the curved surface and accelerates, creating a region of lower air pressure above the wing. The air flowing along the flat plate, on the other hand, flows more slowly and creates a region of higher air pressure below the wing.\n\nThe angle of attack, which is the angle between the wing and the oncoming airflow, is also critical to creating lift. When the wing is at the optimal angle of attack, the air flowing over the curved surface creates a high-pressure area above the wing and a low-pressure area below it, resulting in an upward force called lift.\n\nIn addition to the wing shape and angle of attack, other factors that contribute to an airplane's ability to fly include:\n\n* **Airspeed**: The speed at which the plane is flying. Airspeed is critical to creating lift, as it must be sufficient to create the necessary pressure difference between the upper and lower surfaces of the wing.\n* **Altitude**: The height at which the plane is flying. Altitude affects the air pressure and density, which in turn affects the lift and drag forces.\n* **Wing span**: The length of the wing from tip to tip. A longer wing span can create more lift and improve the plane's stability.\n\nIn summary, airplanes fly due to the combination of the four forces of flight (lift, weight, thrust, and drag) and the shape of the wing, which is designed to produce a difference in air pressure above and below the wing, resulting in an upward force called lift." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 616, 'prompt_tokens': 39, 'total_tokens': 655, 'completion_time': 1.158703423, 'completion_tokens_details': None, 'prompt_time': 0.00316221, 'prompt_tokens_details': None, 'queue_time': 0.132762408, 'total_time': 1.1618656330000001}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d8101-7e7f-7e91-a8fe-dea5cae1e689-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 39, 'output_tokens': 616, 'total_tokens': 655}
