# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("speech.txt", encoding="utf-8")
text_docments = loader.load()
print(text_docments)

# %% [markdown]
# ## 2. PDF Loader

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("example.pdf")  # apni PDF file ka path dein
documents = loader.load()
for doc in documents:
    print(doc.page_content[:200])
    print(doc.metadata)
    print("---")

# %% [markdown]
# ## 3. Web Base Loader

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4

loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-title", "post-content", "post-header")
        )
    )
)

docs = loader.load()
for doc in docs:
    print(doc.page_content[:300])
    print(doc.metadata)
    print("---")

# %% [markdown]
# ## 4. Text Splitters

# %%
from langchain_text_splitters import CharacterTextSplitter

text = "LangChain is a framework. It helps build AI apps. It supports many LLMs. It has loaders, splitters, and chains."

splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=50,
    chunk_overlap=10
)

chunks = splitter.split_text(text)
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {chunk}")

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text = """LangChain is a powerful framework for building AI applications.
It provides document loaders, text splitters, embeddings, and vector stores.
You can use it to build chatbots, Q&A systems, and AI agents.
It supports OpenAI, Anthropic, Google, and many other LLM providers."""

splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

chunks = splitter.split_text(text)
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {chunk}")
    print("---")

# %% [markdown]
# ## 5. HTML Header Text Splitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
]

splitter = HTMLHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on
)

html_content = """
<h1>AI</h1>
<p>AI is powerful</p>
<h2>Machine Learning</h2>
<p>ML is a subset of AI</p>
<h2>Deep Learning</h2>
<p>DL is a subset of ML</p>
<h3>Future</h3>
<p>AI will grow rapidly</p>
"""

documents = splitter.split_text(html_content)
for doc in documents:
    print(doc.page_content)
    print(doc.metadata)
    print("---")

# %% [markdown]
# ## 1. Text Loader
